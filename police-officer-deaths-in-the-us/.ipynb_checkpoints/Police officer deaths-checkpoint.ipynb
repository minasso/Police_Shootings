# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
from pylab import rcParams
rcParams['figure.figsize'] = 14,6

# %%
df = pd.read_csv('clean_data.csv')

# %%
# eliminate unneeded columns, focus on years 2015-2016, rename columns
cols = 'cause_short year dept_name state'.split()
df = df[cols]
df = df[df['year']>2014].copy()
df.reset_index(drop=True, inplace=True)
df.columns='cause year dept state'.split()

# %%
df.head()
# Out:
#                  cause  year                                  dept state
# 0    Struck by vehicle  2015     Jefferson County Sheriff's Office    CO
# 1         Heart attack  2015           Lakeshire Police Department    MO
# 2      Vehicle pursuit  2015      Baltimore City Police Department    MD
# 3  Automobile accident  2015  Texas Department of Criminal Justice    TX
# 4  Automobile accident  2015  Texas Department of Criminal Justice    TX

# %%
df['cause'].value_counts()
df['cause'].value_counts(normalize=True)
# Out:
# Gunfire                     70
# Automobile accident         37
# Heart attack                21
# Heat exhaustion             19
# Vehicular assault           16
# Struck by vehicle           11
# 9/11 related illness         9
# Vehicle pursuit              7
# Bomb                         6
# Motorcycle accident          6
# Gunfire (Accidental)         5
# Animal related               4
# Accidental                   3
# Assault                      3
# Drowned                      3
# Stabbed                      2
# Fire                         2
# Aircraft accident            2
# Duty related illness         2
# Asphyxiation                 1
# Fall                         1
# Weather/Natural disaster     1
# Poisoned                     1
# Training accident            1
# Name: cause, dtype: int64
# Gunfire                     0.300429
# Automobile accident         0.158798
# Heart attack                0.090129
# Heat exhaustion             0.081545
# Vehicular assault           0.068670
# Struck by vehicle           0.047210
# 9/11 related illness        0.038627
# Vehicle pursuit             0.030043
# Bomb                        0.025751
# Motorcycle accident         0.025751
# Gunfire (Accidental)        0.021459
# Animal related              0.017167
# Accidental                  0.012876
# Assault                     0.012876
# Drowned                     0.012876
# Stabbed                     0.008584
# Fire                        0.008584
# Aircraft accident           0.008584
# Duty related illness        0.008584
# Asphyxiation                0.004292
# Fall                        0.004292
# Weather/Natural disaster    0.004292
# Poisoned                    0.004292
# Training accident           0.004292
# Name: cause, dtype: float64

# %%
df.sort_values('cause')
# Out:
#                         cause  year  \
# 54       9/11 related illness  2015
# 157      9/11 related illness  2016
# 16       9/11 related illness  2015
# 86       9/11 related illness  2015
# 87       9/11 related illness  2015
# 13       9/11 related illness  2015
# 41       9/11 related illness  2015
# 5        9/11 related illness  2015
# 114      9/11 related illness  2015
# 228                Accidental  2016
# 63                 Accidental  2015
# 36                 Accidental  2015
# 72          Aircraft accident  2015
# 164         Aircraft accident  2016
# 196            Animal related  2016
# 142            Animal related  2015
# 133            Animal related  2015
# 207            Animal related  2016
# 210              Asphyxiation  2016
# 56                    Assault  2015
# 66                    Assault  2015
# 24                    Assault  2015
# 53        Automobile accident  2015
# 59        Automobile accident  2015
# 55                  Montgomery County Sheriff's Office    GA
# 62                       Bakersfield Police Department    CA
# 34                        Jeanerette Police Department    LA
# 205                   Patton Village Police Department    TX
# 191                       Bibb County Sheriff's Office    GA
# 83                       Missouri State Highway Patrol    MO
# 118                Montgomery County Police Department    MD
# 106                   San Bernardino Police Department    CA
# 113          Georgia Ports Authority Police Department    GA
# 199                      New Orleans Police Department    LA
# 60                             Hutto Police Department    TX
# 161  United States Department of Homeland Security ...    US
# 201                         Pearland Police Department    TX
# 49                               Colorado State Patrol    CO
# 45                           Houston Police Department    TX
# 176               Hillsborough County Sheriff's Office    FL
# 209                      Sterlington Police Department    LA
# 184                       Des Moines Police Department    IA
# 185                       Des Moines Police Department    IA
# 198                          Memphis Police Department    TN
# 65                   Georgia Department of Corrections    GA
# 111                              Colorado State Patrol    CO
# 108                  Ohio University Police Department    OH
#
# [233 rows x 4 columns]

# %%
ax = sns.countplot(x="cause", data=df,order = df['cause'].value_counts().index)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
# Out:
# [<matplotlib.text.Text at 0xffb1a513c8>,
#  <matplotlib.text.Text at 0xffb1a5cbe0>,
#  <matplotlib.text.Text at 0xffb1ad2e80>,
#  <matplotlib.text.Text at 0xffb1ad7978>,
#  <matplotlib.text.Text at 0xffb1ada470>,
#  <matplotlib.text.Text at 0xffb1adaf28>,
#  <matplotlib.text.Text at 0xffb1ae1a20>,
#  <matplotlib.text.Text at 0xffb1ae4518>,
#  <matplotlib.text.Text at 0xffb1ae4fd0>,
#  <matplotlib.text.Text at 0xffb1ae8ac8>,
#  <matplotlib.text.Text at 0xffb1a554a8>,
#  <matplotlib.text.Text at 0xffb1a446a0>,
#  <matplotlib.text.Text at 0xffb1aeb6a0>,
#  <matplotlib.text.Text at 0xffb1aef198>,
#  <matplotlib.text.Text at 0xffb1aefc50>,
#  <matplotlib.text.Text at 0xffb1af4748>,
#  <matplotlib.text.Text at 0xffb1af8240>,
#  <matplotlib.text.Text at 0xffb1af8cf8>,
#  <matplotlib.text.Text at 0xffb1afb7f0>,
#  <matplotlib.text.Text at 0xffb1b002e8>,
#  <matplotlib.text.Text at 0xffb1b00da0>,
#  <matplotlib.text.Text at 0xffb1b04898>,
#  <matplotlib.text.Text at 0xffb1b07390>,
#  <matplotlib.text.Text at 0xffb1b07e48>]

# %% [markdown]
# Focus attention on those causes in which the officer was intentionally killed

# %%
killed = ['Gunfire','Vehicular assault','Vehicle pursuit','Assault','Stabbed']

# %%
dk = df[df['cause'].isin(killed)].copy()
dk.sort_values('cause',inplace=True)
dk.reset_index(drop=True,inplace=True)
sns.countplot(dk.cause,order=dk['cause'].value_counts().index)

# %%
# number of police intentionally killed on duty
len(dk['cause'])
# Out:
# 98
