# 11703                      Sterlington Police Department    LA
# 11704         San Bernardino County Sheriff's Department    CA
# 11705                           Canton Police Department    OH
# 11706                          Norfolk Police Department    VA
# 11707       Smith County Constable's Office - Precinct 5    TX
# 11708  Twin Rivers Unified School District Police Dep...    CA
# 11709                            Omaha Police Department    NE
# 11710                    Rutland County Sheriff's Office    VT
# 11711  Port Authority of Allegheny County Police Depa...    PA
# 11712                     Monroe County Sheriff's Office    TN
# 11713                     Chelan County Sheriff's Office    WA
# 11714           Las Vegas Metropolitan Police Department    NV
# 11715     Unified Police Department of Greater Salt Lake    UT
# 11716                          Anaheim Police Department    CA
# 11717     Westchester County Department of Public Safety    NY
# 11718                   La Salle County Sheriff's Office    TX
# 11719                   Richland Parish Sheriff's Office    LA
# 11720                         San Juan Police Department    TX
# 11721  Cherokee County School District Police Department    GA
# 11722                         Amarillo Police Department    TX
# 11723  United States Department of Homeland Security ...    US
# 11724                   Fountain County Sheriff's Office    IN
# 11725                       Long Beach Police Department    CA
# 11726                           Emmett Police Department    ID
#
# [11727 rows x 4 columns]

# %%
ax = sns.countplot(x="cause", data=df,order = df['cause'].value_counts().index)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
plt.tight_layout()
# Out:
# [<matplotlib.text.Text at 0xbd6b999da0>,
#  <matplotlib.text.Text at 0xbd6b999f28>,
#  <matplotlib.text.Text at 0xbd6da276d8>,
#  <matplotlib.text.Text at 0xbd6da311d0>,
#  <matplotlib.text.Text at 0xbd6da31c88>,
#  <matplotlib.text.Text at 0xbd6da33780>,
#  <matplotlib.text.Text at 0xbd6da38278>,
#  <matplotlib.text.Text at 0xbd6da38d30>,
#  <matplotlib.text.Text at 0xbd6da3c828>,
#  <matplotlib.text.Text at 0xbd6da41320>,
#  <matplotlib.text.Text at 0xbd6da41dd8>,
#  <matplotlib.text.Text at 0xbd6da458d0>,
#  <matplotlib.text.Text at 0xbd6da483c8>,
#  <matplotlib.text.Text at 0xbd6da48e80>,
#  <matplotlib.text.Text at 0xbd6da4c978>,
#  <matplotlib.text.Text at 0xbd6da4f470>,
#  <matplotlib.text.Text at 0xbd6da4ff28>,
#  <matplotlib.text.Text at 0xbd6da53a20>,
#  <matplotlib.text.Text at 0xbd6da58518>,
#  <matplotlib.text.Text at 0xbd6da58fd0>,
#  <matplotlib.text.Text at 0xbd6da5bac8>,
#  <matplotlib.text.Text at 0xbd6da5f5c0>,
#  <matplotlib.text.Text at 0xbd6da640b8>,
#  <matplotlib.text.Text at 0xbd6da64b70>,
#  <matplotlib.text.Text at 0xbd6da67668>,
#  <matplotlib.text.Text at 0xbd6da6b160>,
#  <matplotlib.text.Text at 0xbd6da6bc18>,
#  <matplotlib.text.Text at 0xbd6da70710>,
#  <matplotlib.text.Text at 0xbd6da74208>,
#  <matplotlib.text.Text at 0xbd6da74cc0>,
#  <matplotlib.text.Text at 0xbd6da777b8>,
#  <matplotlib.text.Text at 0xbd6da7c2b0>,
#  <matplotlib.text.Text at 0xbd6da7cd68>,
#  <matplotlib.text.Text at 0xbd6da80860>,
#  <matplotlib.text.Text at 0xbd6da83358>,
#  <matplotlib.text.Text at 0xbd6da83e10>]

# %% [markdown]
# Focus attention on those causes in which the officer was intentionally killed

# %%
killed = ['Gunfire','Vehicular assault','Vehicle pursuit','Assault','Stabbed']

# %%
dk = df[df['cause'].isin(killed)].copy()
dk.sort_values('cause',inplace=True)
dk.reset_index(drop=True,inplace=True)
sns.countplot(dk.cause,order=dk['cause'].value_counts().index)

# %% [markdown]
# Changes over time
